# %%
s = 'hello'

# %%
#s[0] = 'H'

# %%
for i in s:             # for i in range(len(s)):
    print(i)            #     print(s[i])

# %%
s.upper(), s

# %%
s + 'world', s

# %%
s = 'racecar'
s == s[::-1]

# %%
s[0]

# %%
s[1:3]

# %%
s[2:2]

# %%
s[0:]

# %%
s[0:len(s)]

# %%
s[-1], s[-2], s[-3], s[-4], s[-5]

# %%
s[0:5:2], s

# %%
list(range(1, 10, 2))

# %%
list(range(2, 11, 2))

# %%
s[::-1]

# %%
s2 = s[:]
s2

# %%
'0' < '9'

# %%
'0' < 'A'

# %%
'A' < 'a'

# %%
'1.11' < '1.9'

# %%
for idx, i in enumerate(s):
    print(idx, i)

# %%
d = {'name' : 'kim', 'age' : 20}

# %%
for k, v in d:
    print(k, v, sep=":")

# %%
list(enumerate(s))

# %%
a = 'hello'
b = [1, 2, 3, 4, 5]
for i, j in zip(a, b):
    print(i, j)

# %%
'a' in s

# %%
'h' in s

# %%
s.rfind('l')

# %%
s.index('l')

# %%
s.count('l')

# %%
import string

string.ascii_letters

# %%
string.ascii_lowercase

# %%
for i in string.ascii_lowercase:
    print(i, s.count(i))

# %%
int('30', base=16)
# Out:
# 48

# %%
data = list(map(int, input().split()))

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
result = [i**2 for i in data]
result
# Out:
# [1, 4, 9, 16, 25]

# %%
' '.join(map(str, result))
# Out:
# '1 4 9 16 25'

# %%
', '.join(map(str, result))
# Out:
# '1, 4, 9, 16, 25'

# %%
'\n'.join(map(str, result))
# Out:
# '1\n4\n9\n16\n25'

# %%
s = 'hello, world!'
s.title()
# Out:
# 'Hello, World!'

# %%
a = 1
b = 2.0
c = 'hello'
'a: %d, b: %f c: %s' % (a, b, c)
# Out:
# 'a: 1, b: 2.000000 c: hello'

# %%
f'a: {a}, b: {b}, c: {c}'
# Out:
# 'a: 1, b: 2.0, c: hello'
