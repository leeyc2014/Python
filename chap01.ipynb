# %%
1 + 2
# Out:
# 3

# %%
a = 1
b = 2
c = 0
a + b
# Out:
# 3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
a/b
# Out:
# 0.5

# %%
a//b
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %%
1 + 2 * 3
# Out:
# 7

# %%
lst = [1, 3.14, 'hello', True]
lst
# Out:
# [1, 3.14, 'hello', True]

# %%
type(True)
# Out:
# bool

# %%
for l in lst:
    print(type(l), l)
# Out:
# <class 'int'> 1
# <class 'float'> 3.14
# <class 'str'> hello
# <class 'bool'> True

# %%
a = 100_000_000
a
# Out:
# 100000000

# %%
1e5
# Out:
# 100000.0

# %%
3.14e-4
# Out:
# 0.000314

# %%
msg = "Hello world"
msg
# Out:
# 'Hello world'

# %%
type(msg)
# Out:
# str

# %%
msg = 1
type(msg)
# Out:
# int

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
'hello' + "world"
# Out:
# 'helloworld'

# %%
f'{a}, {b}'
# Out:
# '100000000, 2'

# %%
def add(a, b):
    return a/b

# %%
c = add(1, 2)
type(c)
# Out:
# float

# %%
type(lst)
# Out:
# list

# %%
a = 1
b = 2
a, b = b, a     # 파이썬 스타일 swap
a, b
# Out:
# (2, 1)
