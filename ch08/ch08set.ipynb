# %%
set01 = {}
set02 = {1}
set03 = set([1, 2, 3, 4])
print(type(set01))
print(type(set02))
print(type(set03))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'set'>

# %%
set1 = {1, 2, 3}
print(set1)
print(id(set1))
set1 = set1.union({4, 5, 6})
print(set1)
print(id(set1))
set1.add(7)
print(set1)
print(id(set1))
# Out:
# {1, 2, 3}
# 2116540146720
# {1, 2, 3, 4, 5, 6}
# 2116540143136
# {1, 2, 3, 4, 5, 6, 7}
# 2116540143136

# %%
print(set1)
# 1과 5가 같은 집합인지를 파악하는 방법
n = 1
m = 5
if n in set1 and m in set1:
    print('사이클')
else:
    print('X')
# Out:
# {1, 2, 3, 4, 5, 6, 7}
# 사이클
