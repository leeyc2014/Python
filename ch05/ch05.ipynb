# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]
id(d1) == id(d2)
d1 is d2
# Out:
# False

# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]
d1 == d2
# Out:
# True

# %%
data = [1, 2, 3, 4]
del(data[0])
data
# Out:
# [2, 3, 4]

# %%
data = [4, 3, 2, 1]
data.remove(2)
data
# Out:
# [4, 3, 1]

# %%
1 + 2
# Out:
# 3

# %%
'1' + '2'
# Out:
# '12'

# %%
#'1' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 '1' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
int('1') + 2
# Out:
# 3
