# %%
a = 5
if a < 10:
    print("true")
# Out:
# true

# %%
a = -1
if a:
    print("true")
# Out:
# true

# %%
a = 0
if a:
    print("true")

# %%
a = None
if a:
    print("true")

# %%
s = ''
if s:
    print("true")

# %%
a = 3.13
a += 0.01
a == 3.14
# Out:
# False

# %%
a = 3.13
a += 0.01
e = 1e-8
abs(a - 3.14) < e
# Out:
# True

# %%
s1 = 'hello'
s2 = 'hello'
s1 == s2
# Out:
# True

# %%
s1 = str('hello')
s2 = str('hello')
s1 == s2
# Out:
# True

# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]
d1 == d2
# Out:
# True

# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]
d1 == d2
id(d1) == id(d2)
# Out:
# False

# %%
s = 'hello'
'h' in s
# Out:
# True

# %%
d = [1, 2, 3]
3 in d, 4 in d
# Out:
# (True, False)

# %%
a = 10
if a < 5:
    print("true")
elif a > 5:
    print("false")
else:
    pass
# Out:
# false

# %%
not True
# Out:
# False

# %%
b = 'OK' if a > 5 else 'NO'
b
# Out:
# 'OK'

# %%
data = [1,2,3,4,5]
[d for d in data if d % 2 == 0]
# Out:
# [2, 4]

# %%
a = 1
b = 2
if a < b:
    print("true")
    print("true")
else:
    print("false")
    print("false")
# Out:
# true
# true

# %%
data = [5, 2, 1, 3, 6]
data.sort()         # 기존 데이터 변경
data
# Out:
# [1, 2, 3, 5, 6]

# %%
data = [5, 2, 1, 3, 6]
sorted(data)        # 기존 데이터 유지
# Out:
# [1, 2, 3, 5, 6]

# %%
data = [5, 2, 1, 3, 6]
sorted(data, reverse=True)
# Out:
# [6, 5, 3, 2, 1]

# %%
data
# Out:
# [5, 2, 1, 3, 6]

# %%
max(2, 1, 3)
# Out:
# 3

# %%
min(4, 9, 1)
# Out:
# 1
